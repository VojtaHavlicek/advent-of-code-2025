# %% [markdown]
# Ax =1-b  <--- find a solution with smallest hamming weight?

# %%
def weak_compositions(N: int, k: int):
    """
    Yield all weak compositions of N into exactly k parts.
    Parts are >= 0.
    """
    # choose k-1 bar positions among N+k-1 slots
    for bars in combinations(range(N + k - 1), k - 1):
        prev = -1
        parts = []
        for b in bars:
            parts.append(b - prev - 1)
            prev = b
        parts.append(N + k - 1 - prev - 1)
        yield tuple(parts)

def bounded_compositions(total, caps):
    """
    Yield tuples x of len(caps) such that:
      0 <= x[k] <= caps[k] and sum(x) == total
    Prunes early.
    """
    caps = tuple(caps)
    n = len(caps)

    def rec(i, remaining, prefix):
        if i == n - 1:
            if 0 <= remaining <= caps[i]:
                yield prefix + (remaining,)
            return
        # x_i can be at most min(cap, remaining)
        hi = min(caps[i], remaining)
        for x in range(hi + 1):
            # quick feasibility check: can the rest still sum to remaining-x?
            # lower bound is 0, upper bound is sum(caps[i+1:])
            rem2 = remaining - x
            if rem2 < 0:
                break
            if rem2 > sum(caps[i+1:]):
                continue
            yield from rec(i + 1, rem2, prefix + (x,))

    yield from rec(0, total, ())

# %%
appx_max_rank = 0

for _, buttons, req in cases:
    appx_rank = len(buttons)-len(req)
    if appx_rank > appx_max_rank:
        appx_max_rank = appx_rank
        print(f"approximate max_rank for buttons {appx_max_rank}")

    # So the input max rank is about 3. 
    # That's easy, the problem is solved on a very small subspace.
# Out:
# approximate max_rank for buttons 2
# approximate max_rank for buttons 3

# %%
from fractions import Fraction
import sympy as sp

def to_Ab_linear(ineqs, taus):
    """
    Convert a list of linear sympy inequalities to A*tau <= b with rational Fractions.
    Supports only <= or >= and linear expressions.
    """
    A = []
    b = []
    taus = list(taus)

    for ineq in ineqs:
        expr = sp.expand(ineq.lhs - ineq.rhs)  # expr rel 0
        rel = ineq.rel_op

        # normalize to <= 0
        if rel == ">=":
            expr = -expr
        elif rel == "<=":
            pass
        else:
            raise ValueError(f"Unsupported rel {rel}")

        coeffs = [sp.Rational(expr.coeff(t)) for t in taus]
        const = sp.Rational(expr.subs({t: 0 for t in taus}))

        # expr = sum coeffs*tau + const <= 0  =>  sum coeffs*tau <= -const
        A.append([Fraction(int(c.p), int(c.q)) for c in coeffs])
        rhs = -const
        b.append(Fraction(int(rhs.p), int(rhs.q)))

    return A, b

def fm_eliminate_one(A, b, elim_idx):
    """
    Eliminate variable elim_idx from A*x <= b (Fourier–Motzkin).
    """
    P, N, Z = [], [], []
    for row, rhs in zip(A, b):
        c = row[elim_idx]
        if c > 0:
            P.append((row, rhs))
        elif c < 0:
            N.append((row, rhs))
        else:
            Z.append((row, rhs))

    A2, b2 = [], []
    # keep Z constraints (drop column)
    for row, rhs in Z:
        A2.append(row[:elim_idx] + row[elim_idx+1:])
        b2.append(rhs)

    # combine each P with each N
    for rowp, rhsp in P:
        cp = rowp[elim_idx]  # >0
        for rown, rhsn in N:
            cn = rown[elim_idx]  # <0
            newrow = []
            for j in range(len(rowp)):
                if j == elim_idx:
                    continue
                newrow.append(rowp[j]/cp - rown[j]/cn)
            newrhs = rhsp/cp - rhsn/cn
            A2.append(newrow)
            b2.append(newrhs)

    return A2, b2

def fm_bounds_for_var(A, b, var_idx):
    """
    Eliminate all variables except var_idx, returning lower/upper bounds on that variable.
    Returns (lo, hi) as Fractions, possibly infinite (None).
    """
    n = len(A[0])
    # Bring var_idx to last position for easier elimination
    perm = [j for j in range(n) if j != var_idx] + [var_idx]

    def permute_row(row):
        return [row[j] for j in perm]

    Acur = [permute_row(row) for row in A]
    bcur = list(b)

    # eliminate variables 0..n-2 (keep last)
    for elim in range(n-1):
        Acur, bcur = fm_eliminate_one(Acur, bcur, 0)  # always eliminate first var

    # Now system is 1D: a * t <= rhs
    lo = None  # lower bound
    hi = None  # upper bound
    for row, rhs in zip(Acur, bcur):
        a = row[0]
        if a == 0:
            if rhs < 0:
                return None, None  # infeasible
            continue
        bound = rhs / a
        if a > 0:
            # t <= bound
            hi = bound if hi is None else min(hi, bound)
        else:
            # t >= bound  (since dividing flips)
            lo = bound if lo is None else max(lo, bound)
    return lo, hi

# %%
import re
from itertools import combinations
from sympy.solvers.inequalities import reduce_inequalities
import numpy as np

for _, buttons, req in cases:
    R = len(req)
    B = len(buttons)

    M = sp.zeros(R, B)
    for j, indices in enumerate(buttons):
        for i in indices:
            M[i, j] = 1

    b = sp.Matrix(req)
    solution, params = M.gauss_jordan_solve(b)
    
    if len(params) == 0:
        print("Unique solution")
        print(solution)

    print(f"Number of free parameters: {len(params)}")
    if len(params)==0:
        print("No free parameters, skipping")
        continue
    print(solution)
    print(req)

    # How do I find cone where all solution variables are nonnegative and bounded above by req?    
    upper_bounds = [min(req[i] for i in buttons[j]) for j in range(len(buttons))] # upper bound on button presses
    
    # Setup inequalities and find all inputs that satisfy them
    lower_bounds_ineq = [0 <= solution[i] for i in range(len(solution))]
    upper_bounds_ineq = [solution[i] <= upper_bounds[i] for i in range(len(solution))]
    all_ineq = lower_bounds_ineq + upper_bounds_ineq
    all_ineq = [ineq for ineq in all_ineq if ineq.free_symbols]  # drop trivial ones

    # Collect all symbols
    all_symbols = set()
    for ineq in all_ineq:
        all_symbols.update(ineq.free_symbols)

    # Solve inequalities
    A,b = to_Ab_linear(all_ineq, list(all_symbols))

    taus = list(params)  # sympy symbols
    A, b = to_Ab_linear(all_ineq, taus)

    # Iterate over
# Out:
# Unique solution
# Matrix([[18], [1], [0], [9], [7], [16], [8], [12], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[5], [tau1 + 5], [2*tau0 - tau1 - 16], [71 - 3*tau0], [65 - 3*tau0], [tau0 - 1], [tau0 - 18], [tau0], [tau1]])
# [65, 52, 55, 5, 53, 42, 49]
# tau0 18 65/3
# tau1 0 82/3
# Unique solution
# Matrix([[13], [18], [18], [4], [11]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[13], [8], [0], [15], [3], [14]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[39/2 - tau0/2], [16], [35/2 - tau0/2], [27/2 - tau0/2], [tau0/2 + 3/2], [49/2 - tau0/2], [tau0/2 + 25/2], [9], [tau0]])
# [86, 57, 60, 72, 9, 70, 49, 74]
# tau0 0 27
# Number of free parameters: 2
# Matrix([[4*tau0/19 + 11*tau1/19 + 37/19], [-9*tau0/19 + 18*tau1/19 - 88/19], [-4*tau0/19 - 11*tau1/19 + 533/19], [-3*tau0/19 + 6*tau1/19 + 148/19], [11*tau0/19 - 3*tau1/19 + 154/19], [-8*tau0/19 - 3*tau1/19 + 420/19], [-7*tau0/19 - 5*tau1/19 + 529/19], [9*tau0/19 + tau1/19 + 259/19], [-2*tau0/19 - 15*tau1/19 + 485/19], [2*tau0/19 - 4*tau1/19 + 237/19], [tau0], [tau1]])
# [78, 105, 107, 98, 82, 75, 120, 99, 64, 68]
# tau0 0 128/3
# tau1 44/9 97/3
# Unique solution
# Matrix([[13], [18], [5], [12]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[17], [9], [20], [12], [11], [5], [7], [5], [4]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau0 - tau1 + 12], [tau1 - 6], [2*tau1 - 16], [3*tau1 - 39], [-tau0 - tau1 + 29], [18 - tau1], [tau0], [38 - 2*tau1], [tau1]])
# [31, 12, 45, 34, 32, 22, 34, 57]
# tau0 1 16
# tau1 13 18
# Number of free parameters: 2
# Matrix([[13 - tau0], [57/2 - tau1/2], [4 - tau0], [tau0 + tau1/2 + 3/2], [31/2 - tau1/2], [tau1/2 - 19/2], [tau0 + 7], [9], [tau0], [7], [39 - tau1], [tau1]])
# [62, 26, 58, 46, 55, 39, 61, 18, 17, 39]
# tau0 0 4
# tau1 19 31
# Unique solution
# Matrix([[6], [16], [12], [3], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 3
# Matrix([[tau0 - tau1/2 + tau2/2 - 13], [tau2], [21 - tau0], [tau0], [tau1/2 - tau2/2 + 3], [tau1/2 - tau2/2 + 16], [26 - tau1], [tau1], [25 - tau2], [tau2]])
# [11, 62, 45, 21, 50, 24, 45, 36]
# tau0 10 21
# tau1 0 26
# tau2 0 25
# Unique solution
# Matrix([[19], [2], [20]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[3], [17], [7], [15], [13], [2], [11], [12]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau1 + 3], [5], [11 - tau0], [tau0 - 2], [15], [-tau0 + tau1 + 16], [tau1 + 135], [37 - 2*tau1], [tau0], [tau1]])
# [204, 64, 183, 9, 14, 203, 196, 197]
# tau0 2 11
# tau1 0 37/2
# Unique solution
# Matrix([[18], [13], [3], [17], [16], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[2], [17], [17], [11], [3], [2], [18], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[2*tau1 - 8], [-tau0 + tau1 + 14], [tau0 + 2*tau1 - 18], [32 - 2*tau1], [-tau0 - 2*tau1 + 43], [tau0], [tau1 + 6], [tau1]])
# [38, 25, 46, 77, 49, 35]
# tau0 0 71/3
# tau1 4 16
# Unique solution
# Matrix([[19], [15], [20], [12], [13]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[17 - 4*tau0/3], [2*tau0/3 + 11], [2*tau0/3 + 7], [tau0/3 + 6], [tau0/3 + 5], [11 - tau0], [6], [tau0 + 116], [21 - tau0/3], [tau0]])
# [56, 27, 162, 43, 50, 46, 39, 35, 127]
# tau0 0 11
# Number of free parameters: 1
# Matrix([[20 - tau0], [5], [tau0], [tau0 + 11], [19], [8 - tau0], [17 - tau0], [tau0], [1], [1]])
# [44, 25, 8, 59, 30, 40, 69, 76, 56, 76]
# tau0 0 8
# Unique solution
# Matrix([[17], [6], [13], [13], [0], [16]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[34 - 2*tau0], [31 - tau0], [32 - tau0], [16 - tau0], [5], [tau0 - 5], [tau0 + 4], [19], [10], [tau0]])
# [76, 80, 34, 92, 80, 99, 56, 82, 96]
# tau0 5 16
# Number of free parameters: 2
# Matrix([[14], [tau0 + tau1 - 13], [11], [19], [-tau0 - tau1 + 18], [-tau0 - tau1 + 24], [tau0], [tau1 + 9], [tau1]])
# [37, 47, 38, 35, 57, 57, 49]
# tau0 0 18
# tau1 0 18
# Unique solution
# Matrix([[15], [18], [10], [4], [17], [14], [7]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[6], [6], [14], [13]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[11], [10], [5], [19]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[15], [10], [5], [17], [4], [0], [8], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[123], [0], [14]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 3
# Matrix([[-tau0/3 + tau1/3 - 4*tau2/3 + 5/3], [tau1 - tau2 - 16], [-tau0/3 + tau1/3 - tau2/3 + 452/3], [tau0/3 + 2*tau1/3 + tau2/3 - 41/3], [tau1 - 2*tau2 - 10], [21 - tau2], [-tau0/3 - 2*tau1/3 + 8*tau2/3 + 80/3], [-tau0 - 2*tau1 + tau2 + 65], [tau0/3 - tau1/3 - 2*tau2/3 + 34/3], [2*tau0/3 + tau1/3 + 2*tau2/3 + 5/3], [tau0], [tau1], [tau2]])
# [87, 43, 219, 205, 58, 207, 66, 68, 236, 220]
# tau0 0 25
# tau1 16 164/5
# tau2 0 13/2
# Number of free parameters: 2
# Matrix([[tau0 - tau1 - 9], [5 - tau1], [145 - tau0], [tau0], [tau1]])
# [145, 136, 145, 5]
# tau0 9 145
# tau1 0 5
# Unique solution
# Matrix([[10], [0]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[5], [5], [3], [0], [12], [17], [20]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[13], [6], [7], [13], [3], [0]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[39 - 2*tau0], [22 - tau0], [2*tau0 + 113], [tau0 + 8], [30 - 2*tau0], [tau0 - 2], [tau0 - 7], [tau0]])
# [28, 36, 180, 53, 37, 43, 163]
# tau0 7 15
# Number of free parameters: 1
# Matrix([[10 - tau0], [26 - tau0], [5], [tau0], [18]])
# [18, 28, 26, 49]
# tau0 0 10
# Unique solution
# Matrix([[19], [2], [166], [11], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau0 - 4*tau1 + 27], [20 - tau1], [-tau0 + 2*tau1 + 9], [tau1 - 4], [tau0], [tau1 + 3], [19 - tau1], [tau1]])
# [55, 32, 16, 48, 42, 15]
# tau0 0 45
# tau1 4 18
# Number of free parameters: 2
# Matrix([[tau0 + tau1 - 11], [8], [15 - tau1], [-tau0 - tau1 + 25], [tau0], [tau1]])
# [14, 23, 33, 25]
# tau0 0 25
# tau1 0 15
# Number of free parameters: 2
# Matrix([[tau0 + 14], [188], [-tau0 - tau1 + 19], [16 - 2*tau0], [3*tau0 + tau1 - 18], [tau0], [tau1]])
# [218, 19, 218, 205, 207, 221]
# tau0 0 8
# tau1 0 19
# Number of free parameters: 2
# Matrix([[tau1 + 3], [3*tau0/5 + 2*tau1/5 + 48/5], [2*tau0/5 + 8*tau1/5 - 43/5], [-3*tau0/5 - 12*tau1/5 + 212/5], [-tau0/5 - 9*tau1/5 + 124/5], [tau0/5 - 6*tau1/5 + 41/5], [3*tau0/5 + 7*tau1/5 + 458/5], [-tau0/5 + 6*tau1/5 + 14/5], [-3*tau0/5 - 7*tau1/5 + 82/5], [tau0], [tau1]])
# [163, 153, 56, 74, 47, 148, 119, 16, 40]
# tau0 0 118/5
# tau1 3/4 41/5
# Number of free parameters: 1
# Matrix([[24 - tau0], [22 - tau0], [13], [15], [tau0 + 8], [tau0], [8]])
# [45, 36, 82, 47, 8, 32, 23]
# tau0 0 22
# Unique solution
# Matrix([[0], [15], [9], [124], [13], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[33/2 - 3*tau0/2], [17 - 2*tau0], [tau0 - 1], [19/2 - 3*tau0/2], [tau0/2 + 27/2], [2*tau0 - 6], [tau0]])
# [23, 29, 41, 20, 40, 16]
# tau0 3 19/3
# Number of free parameters: 1
# Matrix([[0], [tau0 + 8], [22 - tau0], [22 - 2*tau0], [14], [tau0]])
# [22, 44, 22, 30, 44]
# tau0 0 11
# Unique solution
# Matrix([[0], [13], [16], [104]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[2*tau0 - 32], [58 - 2*tau0], [22 - tau0/2], [tau0 - 4], [tau0 - 10], [45 - 3*tau0/2], [3*tau0/2 - 21], [20 - tau0/2], [38 - 3*tau0/2], [2*tau0 - 27], [tau0]])
# [66, 56, 80, 69, 78, 26, 48, 33, 54, 46]
# tau0 16 76/3
# Number of free parameters: 3
# Matrix([[-5*tau0 - 2*tau1 + 3*tau2 + 321], [4*tau0 + 3*tau1/2 - 5*tau2/2 - 449/2], [2*tau0 - tau2 + 7], [3*tau0 + tau1 - 2*tau2 - 137], [4*tau0 + 2*tau1 - 3*tau2 - 293], [4*tau0 + tau1 - 3*tau2 - 123], [-3*tau0 - tau1/2 + 3*tau2/2 + 169/2], [4*tau0 + 3*tau1/2 - 7*tau2/2 - 413/2], [-2*tau0 - tau1/2 + tau2/2 + 181/2], [-3*tau0 - 3*tau1/2 + 5*tau2/2 + 441/2], [tau0], [tau1], [tau2]])
# [189, 44, 198, 50, 48, 52, 42, 188, 209, 208]
# tau0 4 63/5
# tau1 541/4 168
# tau2 0 93/4
# Number of free parameters: 1
# Matrix([[tau0/2 - 3], [tau0/2 + 13], [38 - 3*tau0/2], [26 - tau0], [tau0]])
# [35, 51, 36, 26]
# tau0 6 76/3
# Number of free parameters: 2
# Matrix([[-tau0 + tau1 - 7], [17], [27 - tau1], [20 - tau1], [-tau0 + 2*tau1 - 16], [6], [tau0], [tau1]])
# [26, 17, 30, 26, 31, 20]
# tau0 0 13
# tau1 8 20
# Unique solution
# Matrix([[9], [6], [4], [8], [18], [8], [7], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[2*tau1 - 13], [tau0 - 2*tau1 + 18], [-tau0 + 5*tau1/2 - 1], [29 - 3*tau1/2], [17 - 3*tau1/2], [23 - tau1/2], [29 - 5*tau1/2], [-tau0 + 3*tau1 - 7], [tau1 + 6], [tau0], [tau1]])
# [46, 39, 74, 73, 55, 58, 40, 86, 68]
# tau0 0 27
# tau1 13/2 34/3
# Unique solution
# Matrix([[7], [16], [197]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0/2 - 11/2], [8], [tau0 + 2], [tau0 - 3], [49/2 - 3*tau0/2], [35 - tau0], [67/2 - 3*tau0/2], [tau0]])
# [64, 16, 65, 65, 40, 53, 61]
# tau0 11 49/3
# Number of free parameters: 2
# Matrix([[-tau0 + tau1/2 + 15], [12 - tau1/2], [-tau0 + tau1/2 - 1], [tau0 - tau1/2 + 16], [24 - tau1/2], [tau0], [tau1]])
# [36, 54, 23, 27, 15]
# tau0 0 11
# tau1 2 24
# Unique solution
# Matrix([[7], [177]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[8], [23 - tau0], [14 - tau0], [tau0 - 5], [8], [20], [36 - 2*tau0], [tau0]])
# [39, 60, 52, 34, 17, 59, 42]
# tau0 5 14
# Unique solution
# Matrix([[19], [20], [2], [18], [6], [12], [4], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[10], [15], [4], [179], [1], [7], [8]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[12], [6], [3], [8], [3], [16], [20]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[4], [9], [20], [13], [13], [17], [11], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[19], [23 - tau0], [23 - tau0], [2*tau0 - 14], [tau0]])
# [32, 42, 42, 23]
# tau0 7 23
# Unique solution
# Matrix([[3], [0], [135]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[0], [21 - tau0], [11], [4], [10], [17 - tau0], [8], [5], [tau0 + 173], [tau0]])
# [223, 54, 27, 227, 221, 17, 35, 216, 206]
# tau0 0 17
# Unique solution
# Matrix([[5], [6], [2], [2], [0], [5], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[6], [12], [2], [15], [178]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[19], [15], [14], [4], [9], [3], [1], [3]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau0 + 10], [-tau0 - tau1 + 17], [-tau0 - tau1 + 19], [11 - tau0], [tau0 + 7], [tau0], [tau1]])
# [21, 19, 38, 24, 47, 29]
# tau0 0 11
# tau1 0 17
# Unique solution
# Matrix([[11], [19]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[-5*tau0/3 - tau1/3 + 18], [-tau0/6 + 5*tau1/12 + 13/4], [tau0/3 - 5*tau1/6 + 33/2], [-3*tau0/2 + tau1/4 + 51/4], [5*tau0/3 - tau1/6 - 7/2], [7*tau0/6 - 5*tau1/12 + 3/4], [2*tau0/3 - 7*tau1/6 + 33/2], [5*tau0/6 + 5*tau1/12 + 13/4], [-tau0 + 3*tau1/2 - 15/2], [-2*tau0/3 + 7*tau1/6 - 23/2], [tau0], [tau1]])
# [35, 31, 50, 30, 31, 38, 42, 40, 27, 47]
# tau0 47/13 103/13
# tau1 155/13 237/13
# Number of free parameters: 1
# Matrix([[6 - tau0], [27/2 - tau0/2], [9], [tau0/2 + 19/2], [tau0/2 + 11/2], [23 - tau0], [tau0]])
# [55, 6, 23, 34, 38, 21]
# tau0 0 6
# Number of free parameters: 1
# Matrix([[18 - tau0], [tau0/2 + 11/2], [tau0/2 + 13/2], [1 - tau0], [9 - tau0], [tau0 - 1], [3*tau0/2 + 15/2], [39/2 - tau0/2], [20], [tau0]])
# [39, 44, 59, 64, 55, 30, 37, 64, 87]
# tau0 1 1
# Number of free parameters: 2
# Matrix([[-tau0 + 2*tau1 + 22], [6 - 2*tau1], [tau1 + 18], [tau0 - 3*tau1 + 152], [tau0], [tau1]])
# [174, 28, 192, 24]
# tau0 0 28
# tau1 0 3
# Unique solution
# Matrix([[6], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 - 10], [188 - tau0], [tau0], [11], [16], [5], [18]])
# [204, 196, 215, 27, 210, 209]
# tau0 10 188
# Number of free parameters: 1
# Matrix([[tau0 - 12], [17], [12], [3], [26 - tau0], [tau0], [11], [13]])
# [67, 29, 12, 37, 39, 43, 29, 25]
# tau0 12 26
# Number of free parameters: 1
# Matrix([[6 - 4*tau0/3], [17 - tau0/3], [2*tau0/3 + 4], [5*tau0/3 + 1], [18], [4*tau0/3 + 20], [17 - tau0/3], [15 - tau0], [2 - tau0/3], [9 - tau0/3], [tau0]])
# [46, 72, 53, 74, 24, 59, 82, 42, 34, 39]
# tau0 0 9/2
# Unique solution
# Matrix([[12], [11], [10], [20], [0]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau0 - 10], [-tau0 + tau1 + 10], [21 - tau0], [36 - tau1], [tau0], [tau1]])
# [57, 57, 36, 36, 21, 11]
# tau0 10 21
# tau1 0 36
# Unique solution
# Matrix([[0], [20], [13], [8], [8], [11]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[17], [13 - tau0], [tau0 + 1], [tau0]])
# [31, 17, 13, 13]
# tau0 0 13
# Number of free parameters: 1
# Matrix([[tau0 - 6], [33 - tau0], [1], [30 - tau0], [18], [9], [tau0], [13], [14]])
# [43, 54, 72, 25, 60, 45, 65, 42]
# tau0 6 30
# Unique solution
# Matrix([[2], [3], [12], [13], [19], [10], [5], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[12], [5], [17], [9], [16]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[-3*tau0 + tau1 + 35], [31 - tau1], [-tau0 - tau1 + 40], [tau1 - 4], [25 - tau0], [tau1 - 10], [2*tau0 + tau1 - 25], [38 - 2*tau0], [tau0 - 13], [tau0 - tau1 + 15], [tau0], [tau1]])
# [53, 40, 97, 101, 79, 57, 27, 108, 120, 76]
# tau0 13 75/4
# tau1 10 27
# Number of free parameters: 2
# Matrix([[-tau0 + tau1 + 8], [-tau0 + tau1 - 4], [tau0 + 2*tau1 - 5], [2*tau0 - tau1 + 16], [tau0 + 3], [19 - 2*tau1], [-2*tau0 + 2*tau1 + 8], [-tau0 - tau1 + 31], [2*tau0 - tau1 + 3], [tau0], [tau1]])
# [56, 44, 43, 30, 41, 53, 26, 73, 41]
# tau0 1 11/2
# tau1 5 19/2
# Number of free parameters: 1
# Matrix([[tau0 + 13], [17], [-tau0], [15 - tau0], [tau0]])
# [28, 32, 13, 0]
# tau0 0 0
# Unique solution
# Matrix([[7], [7], [17], [14], [1], [1], [8], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[-tau0 + tau1 + 8], [3*tau1 - 9], [31 - 3*tau1], [tau0 - 2*tau1 + 18], [30 - 2*tau1], [13 - tau0], [tau0], [tau1]])
# [52, 13, 26, 60, 22, 60]
# tau0 0 13
# tau1 3 31/3
# Number of free parameters: 2
# Matrix([[tau0 - 2*tau1 - 12], [35 - tau0], [-tau0 + tau1 + 37], [-tau0 + tau1 + 39], [tau0 + tau1 - 8], [tau0 - tau1 - 18], [tau1 + 13], [11 - tau1], [tau0], [4 - tau1], [192], [tau1]])
# [60, 224, 247, 262, 243, 234, 69, 294, 241, 269]
# tau0 18 35
# tau1 0 4
# Number of free parameters: 1
# Matrix([[153], [22 - tau0], [21 - tau0], [12], [tau0 + 9], [tau0], [18]])
# [64, 196, 213, 22, 187, 184, 60]
# tau0 0 21
# Number of free parameters: 2
# Matrix([[8], [13], [-tau0 - tau1 + 10], [14], [tau0 + tau1 - 4], [18], [tau0], [13 - tau1], [tau1]])
# [33, 45, 31, 36, 24, 45, 41]
# tau0 0 10
# tau1 0 10
# Unique solution
# Matrix([[17], [8], [2], [19]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[19], [1], [19], [16], [1], [12], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[7], [20], [2], [8], [14], [15], [103], [13], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[19], [5], [155], [11], [20], [0], [0]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[10], [6], [160], [20], [16]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[-tau0 + tau1 + 3], [28 - tau1], [-tau0 + tau1], [43 - 2*tau1], [tau0 - tau1 + 15], [tau0], [tau1]])
# [31, 15, 28, 46, 43]
# tau0 0 43/2
# tau1 0 43/2
# Unique solution
# Matrix([[3], [15], [2], [17], [20], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 - 101], [114 - tau0], [125 - tau0], [tau0], [11], [6], [16], [17]])
# [30, 35, 114, 47, 153, 153, 50]
# tau0 101 114
# Unique solution
# Matrix([[17], [7], [9], [13], [19], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau1 - 163], [-tau0 - tau1 + 181], [-tau0 - tau1/2 + 207/2], [197/2 - tau1/2], [tau0 + tau1/2 - 181/2], [tau1/2 - 153/2], [tau0], [211/2 - tau1/2], [tau1], [20]])
# [222, 68, 51, 38, 73, 55, 214, 39]
# tau0 0 18
# tau1 163 181
# Number of free parameters: 1
# Matrix([[tau0 + 8], [8 - tau0], [9 - tau0], [15], [11], [10], [4 - tau0], [tau0], [tau0]])
# [45, 27, 30, 30, 50, 50, 34, 44, 45]
# tau0 0 4
# Unique solution
# Matrix([[16], [20], [1], [1], [8]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 - 169], [191 - tau0], [tau0]])
# [22, 22, 191, 22]
# tau0 169 191
# Unique solution
# Matrix([[16], [11], [19], [10], [3], [14], [7]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[10 - tau0], [-tau0 + tau1 + 14], [-tau0 - tau1 + 34], [tau0 - tau1 + 8], [tau0], [tau1]])
# [10, 34, 18, 22]
# tau0 0 10
# tau1 0 18
# Unique solution
# Matrix([[14], [2], [15], [5], [12], [8]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[17], [0], [3], [12], [20]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau0], [-tau0 - 2*tau1 + 29], [2*tau1 + 3], [16 - tau0], [-tau0 - 2*tau1 + 27], [3*tau1 + 7], [tau0 + tau1 - 3], [5 - 3*tau1], [tau1 + 19], [tau0], [tau1 + 10], [tau1]])
# [44, 27, 42, 28, 51, 72, 21, 71, 82, 49]
# tau0 4/3 16
# tau1 0 5/3
# Number of free parameters: 2
# Matrix([[-3*tau0/4 + tau1 - 7/2], [-tau0/4 - tau1 + 41/2], [tau0 + tau1 - 20], [29/2 - tau0/4], [19/2 - tau0/4], [193], [27/2 - 5*tau0/4], [-3*tau0/4 - tau1 + 57/2], [3*tau0/2 - tau1 + 15], [tau0], [tau1]])
# [40, 78, 60, 35, 38, 40, 215, 242, 253]
# tau0 2 54/5
# tau1 74/7 138/7
# Unique solution
# Matrix([[9], [5], [5], [14], [0]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[20], [14], [17], [11], [18], [11], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[9], [13], [7], [4], [20 - tau0], [7], [4], [29 - tau0], [tau0], [15]])
# [38, 62, 62, 46, 46, 42, 55, 48, 62, 57]
# tau0 0 20
# Unique solution
# Matrix([[10], [13], [5], [3], [7], [8], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[22 - tau0], [20 - tau0], [tau0 + 13], [5], [tau0 + 15], [22 - tau0], [tau0], [14], [15], [19], [10]])
# [83, 44, 103, 72, 70, 74, 98, 32, 54, 46]
# tau0 0 20
# Number of free parameters: 1
# Matrix([[9], [6], [5], [18 - tau0/2], [10], [13 - tau0/2], [17], [17 - tau0/2], [29 - tau0/2], [tau0]])
# [66, 56, 44, 35, 49, 59, 41, 66, 55]
# tau0 0 26
# Unique solution
# Matrix([[10], [10], [15], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[-2*tau0 - tau1 + 177], [tau0 + tau1 + 4], [14 - tau0], [2*tau0 - 7], [-tau0 - tau1 + 33], [tau0], [tau1]])
# [37, 33, 170, 40, 14]
# tau0 7/2 14
# tau1 0 59/2
# Unique solution
# Matrix([[2], [20], [9], [12], [17], [11], [17], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[12 - tau0], [-tau0 - tau1/2 + 71/2], [tau1/2 + 15/2], [tau0 - tau1/2 + 1/2], [tau0], [tau1]])
# [20, 12, 43, 36]
# tau0 0 12
# tau1 0 25
# Number of free parameters: 1
# Matrix([[17], [12 - tau0], [26 - tau0], [13], [16], [tau0]])
# [39, 26, 29, 33, 25, 42, 55, 42]
# tau0 0 12
# Unique solution
# Matrix([[6], [113], [9], [14]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[7], [19], [2], [18], [1], [18], [0], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[19], [28 - tau0], [25 - tau0], [19 - tau0], [19], [13 - tau0], [tau0], [tau0], [tau0], [8]])
# [65, 33, 72, 40, 71, 66, 52, 63, 68]
# tau0 0 13
# Unique solution
# Matrix([[17], [14], [20], [8], [11], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[1], [12], [5], [1], [14], [20], [19], [6], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[10], [19], [5], [13], [12]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[0], [14], [0], [13], [17], [1], [11], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[17], [17], [111], [18], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[10], [0], [5], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[8], [4], [0], [tau0 - 14], [20], [4], [22 - tau0], [tau0 - 9], [tau0]])
# [33, 49, 16, 21, 24, 38, 26, 12, 28]
# tau0 14 22
# Unique solution
# Matrix([[0], [15], [18], [13], [8], [19], [20], [20]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[16], [0], [17], [9], [15], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[5], [tau0], [9], [153], [2], [32 - 2*tau0], [tau0 - 3], [16 - tau0], [28 - tau0], [32 - tau0], [tau0]])
# [229, 56, 72, 29, 70, 199, 57, 52, 214, 64]
# tau0 3 16
# Unique solution
# Matrix([[17], [14], [16], [8]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[8], [0], [19], [19]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[20], [16], [155], [10], [17], [7]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[18], [19], [107], [15], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 + 4], [4 - tau0], [10], [3*tau0/2 + 13], [14], [tau0/2 - 2], [159 - 3*tau0/2], [tau0/2 + 4], [tau0]])
# [32, 194, 179, 6, 191, 4, 161, 190]
# tau0 4 4
# Number of free parameters: 1
# Matrix([[tau0 - 10], [25 - tau0], [0], [tau0], [5]])
# [5, 25, 20, 25]
# tau0 10 25
# Unique solution
# Matrix([[158], [10], [3], [1], [17], [2], [20], [19], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[tau1], [tau0 - 130], [-tau0 - tau1 + 171], [153 - tau0], [-2*tau0 - tau1 + 322], [tau0], [tau1]])
# [192, 171, 192, 23, 41]
# tau0 130 153
# tau1 0 41
# Number of free parameters: 2
# Matrix([[17/2 - tau1/2], [35/2 - tau1/2], [2 - tau0], [tau0 + 115], [tau0], [23 - tau1], [3*tau1/2 - 33/2], [tau1/2 + 15/2], [tau1]])
# [143, 18, 16, 25, 142, 117, 42]
# tau0 0 2
# tau1 11 17
# Number of free parameters: 1
# Matrix([[32 - tau0], [140 - tau0], [tau0 - 4], [tau0]])
# [32, 136, 140, 168]
# tau0 4 32
# Unique solution
# Matrix([[2], [2], [20], [6], [16], [2], [20], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[6], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[20], [2], [12], [20], [6], [8], [0], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[17], [4], [12], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[29 - tau0], [37 - tau0], [18], [tau0 - 17], [tau0], [14]])
# [63, 12, 30, 29, 44, 37]
# tau0 17 29
# Unique solution
# Matrix([[12], [18], [162], [15], [15]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 - 7], [tau0 + 3], [43 - 2*tau0], [3*tau0 - 31], [12], [20], [33 - 2*tau0], [tau0 - 12], [tau0]])
# [33, 43, 53, 60, 24, 72, 45, 58]
# tau0 12 33/2
# Unique solution
# Matrix([[20], [5], [16], [8], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[0], [10 - tau0], [tau0 + 6], [21 - tau0], [14 - tau0], [tau0 + 17], [14 - tau0], [tau0]])
# [52, 20, 31, 58, 52, 10, 31]
# tau0 0 10
# Number of free parameters: 2
# Matrix([[-tau0 - tau1 + 20], [tau0 - 3], [tau1 + 9], [28 - tau0], [tau0], [tau1]])
# [26, 28, 20, 29]
# tau0 3 20
# tau1 0 17
# Number of free parameters: 2
# Matrix([[tau1 + 2], [tau0 - tau1 - 5], [23 - tau1], [-tau0 - tau1 + 31], [tau0], [tau1]])
# [31, 25, 28, 23]
# tau0 5 31
# tau1 0 13
# Unique solution
# Matrix([[4], [18], [9], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[8], [20], [6], [5]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 3
# Matrix([[tau2 - 9], [28 - tau0], [tau0 - tau1/2 + 3*tau2/2 - 9], [-tau1/2 - tau2 + 431/2], [-2*tau0 + tau1 + tau2/2 + 27/2], [tau0 + tau1/2 - 3*tau2/2 + 1], [-2*tau0 + tau1/2 + 2*tau2 + 15/2], [tau0 - tau1 - 3*tau2/2 + 69/2], [33/2 - tau1/2], [-tau0 + 3*tau2/2 + 25/2], [tau0], [tau1], [tau2]])
# [58, 248, 75, 268, 220, 229, 251, 62, 263, 59]
# tau0 4 28
# tau1 7/2 33
# tau2 9 361/15
# Number of free parameters: 2
# Matrix([[tau1/2 + 9/2], [-tau0 - tau1/2 + 27/2], [tau0 + 3], [-tau0 + tau1/2 + 37/2], [22 - tau0], [15/2 - tau1/2], [17/2 - tau1/2], [23/2 - tau1/2], [tau0], [tau1]])
# [34, 35, 37, 42, 48, 21, 38, 22]
# tau0 0 27/2
# tau1 0 15
# Unique solution
# Matrix([[14], [20], [14], [16], [10], [18], [10], [11], [6]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 + 3], [6], [18 - tau0], [20 - tau0], [tau0], [10], [6], [11]])
# [33, 37, 40, 39, 34, 47, 47]
# tau0 0 18
# Unique solution
# Matrix([[4], [11], [17]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[2], [2], [11], [tau0 - 7], [tau0 + 1], [8], [22 - tau0], [139], [20], [34 - tau0], [tau0]])
# [177, 189, 154, 79, 65, 215, 171, 56, 184, 45]
# tau0 7 22
# Number of free parameters: 2
# Matrix([[-tau0 - tau1 + 22], [tau1 - 2], [19 - tau1], [23 - tau1], [2*tau1 + 5], [23 - tau0], [tau0 - 1], [tau0], [tau1]])
# [67, 22, 23, 43, 49, 50, 63]
# tau0 1 20
# tau1 2 19
# Number of free parameters: 3
# Matrix([[tau0 + 3*tau1/2 - 5*tau2/2 - 22], [-tau0/2 - tau1/4 - 3*tau2/4 + 15], [-tau1/2 + tau2/2 + 10], [-tau1/2 + 3*tau2/2 + 15], [-3*tau0/2 - 3*tau1/4 + 3*tau2/4 + 35], [-tau0/2 - 5*tau1/4 + 5*tau2/4 + 26], [tau0 + 3*tau1/2 - 3*tau2/2 - 8], [tau0], [tau1], [tau2]])
# [43, 43, 57, 56, 49, 52, 44, 33]
# tau0 0 71/3
# tau1 0 88/3
# tau2 0 28/3
# Number of free parameters: 3
# Matrix([[-tau0/3 + tau1/3 - 2*tau2/3 + 25], [-2*tau0/3 - 4*tau1/3 - tau2/3 + 207], [-tau0/3 - 2*tau1/3 - 2*tau2/3 + 21], [tau0/3 - tau1/3 + 8*tau2/3 - 28], [tau0/3 + 5*tau1/3 - 7*tau2/3 + 25], [tau0 + tau1 + 2*tau2 - 35], [-tau0 - tau1 + tau2 + 19], [tau1 - 3*tau2 + 32], [tau0/3 - tau1/3 + 5*tau2/3 - 3], [33 - tau2], [tau0], [tau1], [tau2]])
# [244, 248, 266, 69, 299, 241, 47, 67, 248, 256]
# tau0 0 89/3
# tau1 0 56/3
# tau2 65/9 127/8
# Unique solution
# Matrix([[17], [6], [5], [13], [16], [0], [18]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[14], [9], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[10], [-tau0/2 - 3*tau1/2 + 24], [tau0/2 + tau1/2 + 3], [143 - tau1], [-tau0/2 + tau1/2 + 17], [tau0], [tau1]])
# [163, 37, 27, 51, 143]
# tau0 0 75/2
# tau1 0 16
# Unique solution
# Matrix([[19], [9], [16], [16], [107], [8], [14], [3], [11]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[13], [14], [19], [1], [5], [16], [15], [10], [19], [19]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[tau0 + 142], [13], [2], [tau0 + 12], [20 - tau0], [6 - tau0], [tau0], [10]])
# [34, 29, 45, 171, 30, 15, 160]
# tau0 0 6
# Number of free parameters: 1
# Matrix([[180], [25 - tau0], [tau0 - 2], [33 - tau0], [tau0], [14]])
# [70, 56, 213, 217, 45]
# tau0 2 25
# Number of free parameters: 1
# Matrix([[29 - tau0/2], [11], [17 - tau0/2], [tau0/2 + 2], [tau0]])
# [31, 11, 57, 19]
# tau0 0 34
# Unique solution
# Matrix([[1], [3], [15], [5], [11], [9]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[2*tau0 - 32], [tau0 - 14], [21 - tau0], [31 - tau0], [36 - tau0], [tau0 - 7], [tau0]])
# [46, 42, 67, 35, 50, 31, 17]
# tau0 16 21
# Number of free parameters: 1
# Matrix([[tau0 + 1], [3*tau0 - 34], [22 - tau0], [21 - tau0], [135 - tau0], [tau0 - 3], [tau0]])
# [176, 144, 153, 155, 40, 18]
# tau0 34/3 21
# Number of free parameters: 2
# Matrix([[tau0 - tau1 - 2], [4], [tau0 - 14], [-tau0 + tau1 + 14], [tau0], [170 - tau1], [tau1]])
# [182, 188, 16, 170, 4, 174]
# tau0 14 184
# tau1 0 170
# Number of free parameters: 3
# Matrix([[-tau0/2 + tau2 + 109/2], [tau0 + tau2 - 111], [-tau0/2 - tau1 - tau2 + 149/2], [-tau1 - tau2 + 22], [-tau0/2 + tau1 + 99/2], [tau0 - 2*tau1 + tau2 - 104], [-tau0/2 + tau1 + 123/2], [-tau0 + tau1 - tau2 + 114], [-tau0/2 + tau1 + 133/2], [tau0], [tau1 + 1], [tau1], [tau2]])
# [152, 40, 48, 148, 149, 35, 33, 143, 148, 24]
# tau0 89 119
# tau1 0 10
# tau2 5 22
# Number of free parameters: 1
# Matrix([[tau0 + 17], [5 - 2*tau0], [20], [17], [1 - tau0], [tau0]])
# [39, 42, 37, 21, 38]
# tau0 0 1
# Number of free parameters: 2
# Matrix([[-3*tau0 + 2*tau1 + 37], [tau1 - 6], [-2*tau0 + tau1 + 19], [tau0 - 2*tau1 + 21], [tau0 - tau1 - 2], [tau0 - tau1 + 6], [tau0], [tau1]])
# [50, 56, 23, 34, 32, 40]
# tau0 8 17
# tau1 6 15
# Unique solution
# Matrix([[12], [1]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[2], [13], [13], [1], [137]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[17], [13], [13], [17], [11], [14], [16]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[6], [16], [14]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[15], [1], [112], [1], [9], [18], [10], [5], [17], [3]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 2
# Matrix([[12 - tau0], [-2*tau0 - 2*tau1 + 57], [36 - tau1], [tau0 + tau1 - 11], [13], [19], [2*tau0 + 2*tau1 - 31], [-tau0 - tau1 + 21], [tau0], [tau1]])
# [65, 58, 56, 80, 53, 78, 103, 23, 91]
# tau0 0 12
# tau1 7/2 21
# Number of free parameters: 2
# Matrix([[-2*tau0 - 3*tau1 + 10], [3*tau0 + 7*tau1/2 + 1], [-2*tau0 - 2*tau1 + 23], [-tau0 - tau1/2 + 22], [-3*tau0 - 9*tau1/2 + 20], [3*tau0 + 7*tau1/2 - 5], [tau1/2 + 4], [2*tau0 + 5*tau1/2 + 12], [-tau0 - 3*tau1/2 + 20], [tau0], [tau1]])
# [27, 64, 64, 32, 87, 71, 55, 41, 54]
# tau0 0 5
# tau1 0 10/3
# Number of free parameters: 2
# Matrix([[-tau0/2 + tau1/2 + 13/2], [-tau0/2 - tau1/2 + 53/2], [8], [2], [15 - tau0], [tau0/2 - tau1/2 + 21/2], [tau0], [tau1]])
# [62, 45, 40, 39, 47, 33]
# tau0 0 15
# tau1 0 36
# Number of free parameters: 2
# Matrix([[6 - tau0], [7 - tau0], [20], [23 - tau1], [3], [21 - tau0], [18], [tau0 - tau1 + 4], [tau0], [tau1]])
# [25, 47, 49, 44, 38, 70, 42, 49]
# tau0 0 6
# tau1 0 10
# Number of free parameters: 1
# Matrix([[14 - tau0], [5], [tau0 - 6], [14], [25 - tau0], [tau0]])
# [14, 33, 39, 8, 14, 33, 14]
# tau0 6 14
# Unique solution
# Matrix([[9], [7], [3], [0], [8], [1], [11]])
# Number of free parameters: 0
# No free parameters, skipping
# Unique solution
# Matrix([[1], [19], [10], [19], [10], [10]])
# Number of free parameters: 0
# No free parameters, skipping
# Number of free parameters: 1
# Matrix([[10 - tau0], [15 - tau0/2], [tau0/2 + 8], [tau0 + 10], [13 - 3*tau0/2], [tau0]])
# [31, 23, 38, 20, 10]
# tau0 0 26/3

# %%
import re
from itertools import combinations
from ortools.sat.python import cp_model

def parse_buttons(buttons): 
    # Get button vectors 
    button_indices = []
    for b in buttons:
            indices = [int(x) for x in b.strip('()').split(',')]
            button_indices.append(tuple(indices))

    return button_indices

cases = []
with open('input.txt', 'r') as f:
    data = f.readlines()
    for k in range(len(data)):
        diagram = re.findall('\[.*\]', data[k])[0].strip('[]')
        buttons = re.findall('\(\d[,\d]*\)', data[k])
        reqs = [int(x) for x in re.findall('\{.*\}', data[k])[0].strip('{}').split(',')]

        buttons = parse_buttons(buttons)
        cases.append((diagram, buttons, reqs))

_, buttons, req = cases[0]

def solve_buttons_cpsat(req, buttons):
    """
    req: list[int] length R
    buttons: list[tuple[int]] length B; button j affects requirements in buttons[j]
    """
    R = len(req)
    B = len(buttons)

    # Upper bounds per button (safe)
    ub = [min(req[i] for i in idxs) if idxs else 0 for idxs in buttons]

    model = cp_model.CpModel()
    x = [model.NewIntVar(0, ub[j], f"x{j}") for j in range(B)]

    # Constraints: sum_{j affecting i} x_j == req[i]
    for i in range(R):
        model.Add(sum(x[j] for j in range(B) if i in buttons[j]) == req[i])

    # Objective: minimize total presses
    model.Minimize(sum(x))

    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = 10.0  # optional
    status = solver.Solve(model)

    if status in (cp_model.OPTIMAL, cp_model.FEASIBLE):
        sol = [solver.Value(xj) for xj in x]
        return sol, sum(sol), status
    return None, None, status

total_presses = 0
for _, buttons, req in cases:
    sol, total, status = solve_buttons_cpsat(req, buttons)
    if sol is not None:
        total_presses += total
    else:
        print(f"No solution found, status {status}")

total_presses
# Out:
# 21021

# %%
pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.14.6206-cp310-cp310-macosx_11_0_arm64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 8.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ortools) (2.2.6)
# Collecting pandas>=2.0.0
#   Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting immutabledict>=3.0.0
#   Downloading immutabledict-4.2.2-py3-none-any.whl (4.7 kB)
# Collecting absl-py>=2.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting typing-extensions>=4.12
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting protobuf<6.32,>=6.31.1
#   Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 KB 8.8 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 KB 8.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vojtahavlicek/Library/Python/3.10/lib/python/site-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: six>=1.5 in /Users/vojtahavlicek/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Installing collected packages: pytz, tzdata, typing-extensions, protobuf, immutabledict, absl-py, pandas, ortools
# Successfully installed absl-py-2.3.1 immutabledict-4.2.2 ortools-9.14.6206 pandas-2.3.3 protobuf-6.31.1 pytz-2025.2 typing-extensions-4.15.0 tzdata-2025.3
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
